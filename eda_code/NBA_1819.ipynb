# %%
import pandas as pd
import numpy as np

# %%
data_1819 = pd.read_csv('C:/2020_thesis_originaldata/NBA_PBP_2018_2019.csv')
data_1819.head()
# Out:
#                             URL GameType                        Location  \
# 0  /boxscores/201810160BOS.html  regular  TD Garden Boston Massachusetts
# 1  /boxscores/201810160BOS.html  regular  TD Garden Boston Massachusetts
# 2  /boxscores/201810160BOS.html  regular  TD Garden Boston Massachusetts
# 3  /boxscores/201810160BOS.html  regular  TD Garden Boston Massachusetts
# 4  /boxscores/201810160BOS.html  regular  TD Garden Boston Massachusetts
#
#               Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0  October 16 2018  8:00 PM         BOS        1      720      PHI
# 1  October 16 2018  8:00 PM         BOS        1      700      PHI
# 2  October 16 2018  8:00 PM         BOS        1      700      PHI
# 3  October 16 2018  8:00 PM         BOS        1      675      PHI
# 4  October 16 2018  8:00 PM         BOS        1      673      PHI
#
#                                             AwayPlay  ...  FreeThrowNum  \
# ...

# %%
data_1819.drop(columns = ['Location','Date','Time','WinningTeam','JumpballAwayPlayer','JumpballHomePlayer','JumpballPoss','TimeoutTeam'], inplace= True)

# %%
data_1819.drop(columns = ['ShotDist','Assister'], inplace= True)

# %%
data_1819 = data_1819[['URL','GameType','HomeTeam','AwayTeam','Quarter','SecLeft','HomePlay','AwayPlay','HomeScore','AwayScore','Shooter', 'ShotType',
       'ShotOutcome', 'Blocker', 'FoulType', 'Fouler',
       'Fouled', 'Rebounder', 'ReboundType', 'ViolationPlayer',
       'ViolationType', 'FreeThrowShooter', 'FreeThrowOutcome', 'FreeThrowNum',
       'EnterGame', 'LeaveGame', 'TurnoverPlayer', 'TurnoverType',
       'TurnoverCause', 'TurnoverCauser']]

# %%
len(data_1819.columns)
# Out:
# 30

# %%
data_1819['URL'] = data_1819.URL.str[15:23]
data_1819
# Out:
#              URL GameType HomeTeam AwayTeam  Quarter  SecLeft  \
# 0       10160BOS  regular      BOS      PHI        1      720
# 1       10160BOS  regular      BOS      PHI        1      700
# 2       10160BOS  regular      BOS      PHI        1      700
# 3       10160BOS  regular      BOS      PHI        1      675
# 4       10160BOS  regular      BOS      PHI        1      673
# 5       10160BOS  regular      BOS      PHI        1      668
# 6       10160BOS  regular      BOS      PHI        1      663
# 7       10160BOS  regular      BOS      PHI        1      658
# 8       10160BOS  regular      BOS      PHI        1      655
# 9       10160BOS  regular      BOS      PHI        1      636
# 10      10160BOS  regular      BOS      PHI        1      635
# 11      10160BOS  regular      BOS      PHI        1      632
# 12      10160BOS  regular      BOS      PHI        1      629
# 13      10160BOS  regular      BOS      PHI        1      622
# ...

# %%
data_1819.GameType[data_1819.GameType == 'regular'] = 'reg'
data_1819.GameType[data_1819.GameType == 'playoff'] = 'plo'
# Out:
# C:\Users\drlim\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\drlim\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_1819['ShotType'] = data_1819.ShotType.str[0]
data_1819[['ShotType']]
data_1819['ShotType'] = data_1819.ShotType.astype('float')
data_1819[['ShotType']]
# Out:
#         ShotType
# 0            NaN
# 1            3.0
# 2            NaN
# 3            3.0
# 4            NaN
# 5            NaN
# 6            2.0
# 7            NaN
# 8            2.0
# 9            2.0
# 10           NaN
# 11           3.0
# 12           NaN
# 13           2.0
# 14           NaN
# 15           2.0
# 16           NaN
# 17           2.0
# 18           NaN
# 19           2.0
# 20           NaN
# 21           NaN
# 22           2.0
# 23           NaN
# 24           2.0
# 25           NaN
# 26           2.0
# 27           NaN
# 28           2.0
# 29           NaN
# ...          ...
# 613641       NaN
# 613642       NaN
# 613643       3.0
# 613644       NaN
# 613645       2.0
# 613646       NaN
# 613647       NaN
# 613648       2.0
# 613649       NaN
# 613650       NaN
# 613651       NaN
# 613652       NaN
# 613653       NaN
# 613654       NaN
# 613655       NaN
# 613656       NaN
# 613657       NaN
# 613658       NaN
# 613659       3.0
# 613660       NaN
# ...

# %%
data_1819.ShotOutcome[data_1819.ShotOutcome == 'make'] = 1

data_1819.ShotOutcome[data_1819.ShotOutcome == 'miss'] = 0

data_1819[['ShotOutcome']]
# Out:
# C:\Users\drlim\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\drlim\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        ShotOutcome
# 0              NaN
# 1                0
# 2              NaN
# 3                0
# 4              NaN
# 5              NaN
# 6                0
# 7              NaN
# 8                1
# 9                0
# 10             NaN
# 11               0
# ...

# %%
data_1819.FreeThrowOutcome[data_1819.FreeThrowOutcome == 'make'] = 1

data_1819.FreeThrowOutcome[data_1819.FreeThrowOutcome == 'miss'] = 0

data_1819[['FreeThrowOutcome']]
# Out:
# C:\Users\drlim\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\drlim\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        FreeThrowOutcome
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# ...

# %%
data_1819 = data_1819[data_1819.Quarter.isin([1,2,3,4])]

data_1819.shape
# Out:
# (609023, 30)

# %%
data_1819 = data_1819[data_1819.ViolationType.isnull()]

data_1819.ViolationType.value_counts()
# Out:
# Series([], Name: ViolationType, dtype: int64)

# %%
data_1819.drop(columns= ['ViolationPlayer','ViolationType'],inplace=True)

data_1819.shape
# Out:
# (606798, 28)

# %%
data_1819.FreeThrowNum = data_1819.FreeThrowNum[data_1819.FreeThrowNum != 'technical']

data_1819
# Out:
#              URL GameType HomeTeam AwayTeam  Quarter  SecLeft  \
# 0       10160BOS      reg      BOS      PHI        1      720
# 1       10160BOS      reg      BOS      PHI        1      700
# 2       10160BOS      reg      BOS      PHI        1      700
# 3       10160BOS      reg      BOS      PHI        1      675
# 4       10160BOS      reg      BOS      PHI        1      673
# 5       10160BOS      reg      BOS      PHI        1      668
# 6       10160BOS      reg      BOS      PHI        1      663
# 7       10160BOS      reg      BOS      PHI        1      658
# 8       10160BOS      reg      BOS      PHI        1      655
# 9       10160BOS      reg      BOS      PHI        1      636
# 10      10160BOS      reg      BOS      PHI        1      635
# 11      10160BOS      reg      BOS      PHI        1      632
# 12      10160BOS      reg      BOS      PHI        1      629
# 13      10160BOS      reg      BOS      PHI        1      622
# ...

# %%
data_1819['TurnoverType'][data_1819['TurnoverCause'] =='steal'] = 'steal'
# Out:
# C:\Users\drlim\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
common_tov_array = data_1819[data_1819['TurnoverType'].notnull()].TurnoverType.unique()
common_tov_array = common_tov_array[common_tov_array != 'steal']

# %%
data_1819.TurnoverType[data_1819.TurnoverType.isin(common_tov_array)] = 'common_tov'
data_1819.TurnoverType.value_counts()
# Out:
# C:\Users\drlim\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# steal         19831
# common_tov    16766
# Name: TurnoverType, dtype: int64

# %%
data_1819.drop(columns = ['TurnoverCause','TurnoverCauser'], inplace=True)
data_1819
# Out:
#              URL GameType HomeTeam AwayTeam  Quarter  SecLeft  \
# 0       10160BOS      reg      BOS      PHI        1      720
# 1       10160BOS      reg      BOS      PHI        1      700
# 2       10160BOS      reg      BOS      PHI        1      700
# 3       10160BOS      reg      BOS      PHI        1      675
# 4       10160BOS      reg      BOS      PHI        1      673
# 5       10160BOS      reg      BOS      PHI        1      668
# 6       10160BOS      reg      BOS      PHI        1      663
# 7       10160BOS      reg      BOS      PHI        1      658
# 8       10160BOS      reg      BOS      PHI        1      655
# 9       10160BOS      reg      BOS      PHI        1      636
# 10      10160BOS      reg      BOS      PHI        1      635
# 11      10160BOS      reg      BOS      PHI        1      632
# 12      10160BOS      reg      BOS      PHI        1      629
# 13      10160BOS      reg      BOS      PHI        1      622
# ...

# %%
data_1819.columns
# Out:
# Index(['URL', 'GameType', 'HomeTeam', 'AwayTeam', 'Quarter', 'SecLeft',
#        'HomePlay', 'AwayPlay', 'HomeScore', 'AwayScore', 'Shooter', 'ShotType',
#        'ShotOutcome', 'Blocker', 'FoulType', 'Fouler', 'Fouled', 'Rebounder',
#        'ReboundType', 'FreeThrowShooter', 'FreeThrowOutcome', 'FreeThrowNum',
#        'EnterGame', 'LeaveGame', 'TurnoverPlayer', 'TurnoverType'],
#       dtype='object')

# %%
person_col_list = ['Shooter','Blocker','Fouler','Fouled','Rebounder','FreeThrowShooter','TurnoverPlayer']

# %%
data_1819[person_col_list[0]].str[:-5]
# Out:
# 0                   NaN
# 1         R. Covington
# 2                   NaN
# 3             J. Tatum
# 4                   NaN
# 5                   NaN
# 6             J. Brown
# 7                   NaN
# 8            J. Embiid
# 9             J. Tatum
# 10                  NaN
# 11            D. Saric
# 12                  NaN
# 13          G. Hayward
# 14                  NaN
# 15           J. Embiid
# 16                  NaN
# 17            J. Brown
# 18                  NaN
# 19            M. Fultz
# 20                  NaN
# 21                  NaN
# 22           J. Embiid
# 23                  NaN
# 24           J. Embiid
# 25                  NaN
# 26            J. Tatum
# 27                  NaN
# 28            M. Fultz
# 29                  NaN
#               ...
# 613640              NaN
# 613641              NaN
# 613642              NaN
# 613643      K. Leonard
# 613644              NaN
# 613645      D. Cousins
# 613646              NaN
# 613647              NaN
# ...

# %%
data_1819[person_col_list]
# Out:
#                    Shooter           Blocker             Fouler  \
# 0                      NaN               NaN                NaN
# 1       R. Covington - PHI               NaN                NaN
# 2                      NaN               NaN                NaN
# 3           J. Tatum - BOS               NaN                NaN
# 4                      NaN               NaN                NaN
# 5                      NaN               NaN                NaN
# 6           J. Brown - BOS               NaN                NaN
# 7                      NaN               NaN                NaN
# 8          J. Embiid - PHI               NaN                NaN
# 9           J. Tatum - BOS               NaN                NaN
# 10                     NaN               NaN                NaN
# 11          D. Saric - PHI               NaN                NaN
# 12                     NaN               NaN                NaN
# 13        G. Hayward - BOS               NaN                NaN
# ...

# %%
for i in person_col_list:
    data_1819[i] = data_1819[i].str[:-5]

# %%
#df[df['A'].str.contains("hello")]
data_1819 = data_1819[~data_1819['HomePlay'].str.contains('timeout',na=False)]
data_1819 = data_1819[~data_1819['AwayPlay'].str.contains('timeout',na=False)]

# %%
#df[df['A'].str.contains("hello")]
data_1819 = data_1819[~data_1819['HomePlay'].str.contains('technical',na=False)]
data_1819 = data_1819[~data_1819['AwayPlay'].str.contains('technical',na=False)]

# %%
data_1819.reset_index(inplace=True)
data_1819.drop(columns = ['index'],inplace=True)
data_1819
# Out:
#              URL GameType HomeTeam AwayTeam  Quarter  SecLeft  \
# 0       10160BOS      reg      BOS      PHI        1      720
# 1       10160BOS      reg      BOS      PHI        1      700
# 2       10160BOS      reg      BOS      PHI        1      700
# 3       10160BOS      reg      BOS      PHI        1      675
# 4       10160BOS      reg      BOS      PHI        1      673
# 5       10160BOS      reg      BOS      PHI        1      668
# 6       10160BOS      reg      BOS      PHI        1      663
# 7       10160BOS      reg      BOS      PHI        1      658
# 8       10160BOS      reg      BOS      PHI        1      655
# 9       10160BOS      reg      BOS      PHI        1      636
# 10      10160BOS      reg      BOS      PHI        1      635
# 11      10160BOS      reg      BOS      PHI        1      632
# 12      10160BOS      reg      BOS      PHI        1      629
# 13      10160BOS      reg      BOS      PHI        1      622
# ...

# %%
data_1819reg = data_1819[data_1819.GameType == 'reg']
data_1819plo = data_1819[data_1819.GameType == 'plo']
data_1819plo.reset_index(inplace=True)
data_1819plo.drop(columns = ['index'], inplace=True)
data_1819reg.shape[0] + data_1819plo.shape[0] == data_1819.shape[0]
# Out:
# C:\Users\drlim\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# True

# %%
data_1819reg.drop(columns = ['GameType'], inplace = True)
data_1819plo.drop(columns = ['GameType'], inplace = True)

# %%
data_1819reg.to_csv('C:/2020_thesis_repo/original_data/data_1819reg.csv')
data_1819plo.to_csv('C:/2020_thesis_repo/original_data/data_1819plo.csv')
